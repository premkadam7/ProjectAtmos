# %% [markdown]
# # 02 - Feature Engineering
#
# In this notebook, we transform the raw data into ML-ready features. We construct lag features, rolling windows, cyclical time encodings, and weather cross-features to capture physical and temporal dynamics.

# %%
import pandas as pd
import numpy as np

# Load merged dataset
df = pd.read_csv('../data_store/cache/features_delhi.csv')
print(f'Engineered features shape: {df.shape}')
print(df.columns.tolist())
# Out:
# Engineered features shape: (473040, 51)
# ['timestamp', 'station', 'lat', 'lon', 'pm25', 'pm10', 'co', 'no2', 'so2', 'o3', 'aqi', 'temperature_2m', 'relative_humidity_2m', 'wind_speed_10m', 'wind_direction_10m', 'surface_pressure', 'precipitation', 'hour', 'day_of_week', 'month', 'is_weekend', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'dow_sin', 'dow_cos', 'is_stubble_season', 'is_diwali', 'is_new_year', 'pm25_lag_1h', 'aqi_lag_1h', 'pm25_lag_3h', 'aqi_lag_3h', 'pm25_lag_6h', 'aqi_lag_6h', 'pm25_lag_12h', 'aqi_lag_12h', 'pm25_lag_24h', 'aqi_lag_24h', 'pm25_rolling_6h', 'aqi_rolling_6h', 'pm25_rolling_12h', 'aqi_rolling_12h', 'pm25_rolling_24h', 'aqi_rolling_24h', 'wind_humidity_cross', 'temp_wind_cross', 'ward_id', 'ndvi_mean', 'population_density_per_km2']

# %% [markdown]
# ## Visualizing Feature Distributions

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.hist(df['pm25_rolling_12h'].dropna(), bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of 12-Hour Rolling PM2.5')
plt.xlabel('PM2.5')
plt.ylabel('Frequency')
plt.show()
